# %%
# !pip install kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d airbnb/seattle
# !unzip seattle.zip -d seattle_dataset
# Out:
# ...
# mv: cannot stat 'kaggle.json': No such file or directory
# seattle.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  seattle.zip
# replace seattle_dataset/calendar.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import numpy as np

# %%
reviews = pd.read_csv("/content/seattle_dataset/reviews.csv", encoding='latin-1')

# %%
listings = pd.read_csv("/content/seattle_dataset/listings.csv", encoding='latin-1')

# %%
calendar = pd.read_csv("/content/seattle_dataset/calendar.csv", encoding='latin-1')

# %%
calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
listings.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %% [markdown]
# Додамо до таблиці listings відгуки людей, використовуючи merge

# %%
pd.merge(listings,reviews,left_on=['id'],right_on=['listing_id'])
# Out:
#           id_x                           listing_url       scrape_id  \
# 0       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 1       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 2       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 3       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 4       241032   https://www.airbnb.com/rooms/241032  20160104002432
# ...        ...                                   ...             ...
# 84844  3383329  https://www.airbnb.com/rooms/3383329  20160104002432
# 84845  3383329  https://www.airbnb.com/rooms/3383329  20160104002432
# 84846  8101950  https://www.airbnb.com/rooms/8101950  20160104002432
# 84847  8902327  https://www.airbnb.com/rooms/8902327  20160104002432
# 84848  8902327  https://www.airbnb.com/rooms/8902327  20160104002432
#
#       last_scraped                                 name  \
# 0       2016-01-04         Stylish Queen Anne Apartment
# ...

# %%
pd.merge(listings,reviews,left_on=['id'],right_on=['listing_id'], how='inner')
# Out:
#           id_x                           listing_url       scrape_id  \
# 0       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 1       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 2       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 3       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 4       241032   https://www.airbnb.com/rooms/241032  20160104002432
# ...        ...                                   ...             ...
# 84844  3383329  https://www.airbnb.com/rooms/3383329  20160104002432
# 84845  3383329  https://www.airbnb.com/rooms/3383329  20160104002432
# 84846  8101950  https://www.airbnb.com/rooms/8101950  20160104002432
# 84847  8902327  https://www.airbnb.com/rooms/8902327  20160104002432
# 84848  8902327  https://www.airbnb.com/rooms/8902327  20160104002432
#
#       last_scraped                                 name  \
# 0       2016-01-04         Stylish Queen Anne Apartment
# ...

# %%
pd.merge(listings,reviews,left_on=['id'],right_on=['listing_id'], how='inner',indicator=True)
# Out:
#           id_x                           listing_url       scrape_id  \
# 0       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 1       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 2       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 3       241032   https://www.airbnb.com/rooms/241032  20160104002432
# 4       241032   https://www.airbnb.com/rooms/241032  20160104002432
# ...        ...                                   ...             ...
# 84844  3383329  https://www.airbnb.com/rooms/3383329  20160104002432
# 84845  3383329  https://www.airbnb.com/rooms/3383329  20160104002432
# 84846  8101950  https://www.airbnb.com/rooms/8101950  20160104002432
# 84847  8902327  https://www.airbnb.com/rooms/8902327  20160104002432
# 84848  8902327  https://www.airbnb.com/rooms/8902327  20160104002432
#
#       last_scraped                                 name  \
# 0       2016-01-04         Stylish Queen Anne Apartment
# ...
