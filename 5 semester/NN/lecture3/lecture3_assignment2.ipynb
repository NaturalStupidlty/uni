# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4], ['a','b','c','d'])

# %%
d = {'Kyiv': 1000, 'London': 300, 'Barcelona': None}
cities = pd.Series(d)

# %%
print(cities['Kyiv'])
# Out:
# 1000.0

# %%
print(cities['Kyiv'], cities['London'])
# Out:
# 1000.0 300.0

# %%
print(s['a': 'c'])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(cities[cities < 1000])
# Out:
# London    300.0
# dtype: float64

# %%
cities['Kyiv'] = 100

# %%
cities[cities < 1000] = 3
print(cities['Kyiv'])
# Out:
# 3.0

# %%
print(cities[cities > 0] * 3)
# Out:
# Kyiv      9.0
# London    9.0
# dtype: float64

# %%
print(cities[cities.isnull()])
# Out:
# Barcelona   NaN
# dtype: float64

# %%
print(cities[cities.notnull()])
# Out:
# Kyiv      3.0
# London    3.0
# dtype: float64

# %%
import pandas as pd
import numpy as np

# %%
# !pip install kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d nikitakrutogolov/citibike
# !unzip citibike.zip -d citibike_dataset
# Out:
# ...
#   0% 0.00/1.98k [00:00<?, ?B/s]
# 100% 1.98k/1.98k [00:00<00:00, 5.45MB/s]
# Archive:  citibike.zip
#   inflating: citibike_dataset/citibike.csv

# %%
data = pd.read_csv("/content/citibike_dataset/citibike.csv", encoding='latin-1')

# %%
data.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3           687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
# 4           609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
data.head(3)
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
#
#    end station id             end station name  end station latitude  \
# 0             347  Greenwich St & W Houston St             40.728846
# 1             466              W 25 St & 6 Ave             40.743954
# 2            3107     Bedford Ave & Nassau Ave             40.723117
#
#    end station longitude  bikeid    usertype  birth year  gender
# ...

# %%
data.tail()
# Out:
#     tripduration          starttime           stoptime  start station id  \
# 25           659  7/1/2016 00:02:13  7/1/2016 00:13:13               237
# 26          1226  7/1/2016 00:02:20  7/1/2016 00:22:46               127
# 27          1735  7/1/2016 00:02:29  7/1/2016 00:31:24               293
# 28           209  7/1/2016 00:02:31  7/1/2016 00:06:01               410
# 29           492  7/1/2016 00:02:32  7/1/2016 00:10:44               481
#
#          start station name  start station latitude  start station longitude  \
# 25          E 11 St & 2 Ave               40.730473               -73.986724
# 26    Barrow St & Hudson St               40.731724               -74.006744
# 27    Lafayette St & E 8 St               40.730287               -73.990765
# 28  Suffolk St & Stanton St               40.720664               -73.985180
# 29     S 3 St & Bedford Ave               40.712605               -73.962644
#
# ...

# %%
data.shape
# Out:
# (30, 15)

# %%
data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
data.columns[8]
# Out:
# 'end station name'

# %%
data.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                 float64
# gender                       int64
# dtype: object

# %%
data[['starttime','start station name']].head()
# Out:
#            starttime     start station name
# 0  7/1/2016 00:00:02       W 20 St & 11 Ave
# 1  7/1/2016 00:00:18  Lafayette St & E 8 St
# 2  7/1/2016 00:00:19    N 8 St & Driggs Ave
# 3  7/1/2016 00:00:24       W 20 St & 11 Ave
# 4  7/1/2016 00:00:31  Greenwich Ave & 8 Ave

# %%
data.iloc[-1]
# Out:
# tripduration                                    492
# starttime                         7/1/2016 00:02:32
# stoptime                          7/1/2016 00:10:44
# start station id                                481
# start station name             S 3 St & Bedford Ave
# start station latitude                    40.712605
# start station longitude                  -73.962644
# end station id                                 3109
# end station name           Banker St & Meserole Ave
# end station latitude                       40.72606
# end station longitude                     -73.95621
# bikeid                                        23648
# usertype                                 Subscriber
# birth year                                   1991.0
# gender                                            2
# Name: 29, dtype: object

# %%
data.iloc[-1,4]
# Out:
# 'S 3 St & Bedford Ave'

# %%
data.loc[1,'tripduration']
# Out:
# 492

# %%
data.loc[0:4]
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3           687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
# 4           609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
data.iloc[0:4]
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3           687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
#
#    end station id             end station name  end station latitude  \
# 0             347  Greenwich St & W Houston St             40.728846
# 1             466              W 25 St & 6 Ave             40.743954
# ...

# %%
data[(data['tripduration'] < 1000) & (data['gender'] == 1)]
# Out:
#     tripduration          starttime           stoptime  start station id  \
# 1            492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 5            672  7/1/2016 00:00:45  7/1/2016 00:11:57               459
# 6            466  7/1/2016 00:00:49  7/1/2016 00:08:35               128
# 7            556  7/1/2016 00:00:51  7/1/2016 00:10:07               433
# 8            767  7/1/2016 00:00:51  7/1/2016 00:13:39               254
# 11           777  7/1/2016 00:01:04  7/1/2016 00:14:02               372
# 12           306  7/1/2016 00:01:07  7/1/2016 00:06:13               264
# 21           362  7/1/2016 00:02:01  7/1/2016 00:08:04               157
# 23           351  7/1/2016 00:02:05  7/1/2016 00:07:57               490
# 24           328  7/1/2016 00:02:11  7/1/2016 00:07:40               492
# 25           659  7/1/2016 00:02:13  7/1/2016 00:13:13               237
# 28           209  7/1/2016 00:02:31  7/1/2016 00:06:01               410
#
# ...

# %%
data.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count     30.000000         30.000000               30.000000
# mean     797.466667        529.433333               40.731871
# std      558.310860        714.275021                0.018098
# min      191.000000        127.000000               40.690893
# 25%      464.500000        269.000000               40.723604
# 50%      582.500000        359.500000               40.730380
# 75%     1053.000000        459.000000               40.744569
# max     2229.000000       3150.000000               40.775369
#
#        start station longitude  end station id  end station latitude  \
# count                30.000000       30.000000             30.000000
# mean                -73.992881      573.700000             40.733723
# std                   0.017158      697.392639              0.015794
# min                 -74.009447      174.000000             40.689888
# ...

# %%
data.describe(include=[np.object0])
# Out:
#                 starttime           stoptime start station name  \
# count                  30                 30                 30
# unique                 27                 30                 23
# top     7/1/2016 00:00:51  7/1/2016 00:11:47   W 20 St & 11 Ave
# freq                    2                  1                  3
#
#                    end station name    usertype
# count                            30          30
# unique                           26           2
# top     Greenwich St & W Houston St  Subscriber
# freq                              3          25

# %%
data['gender'].value_counts(normalize=True)
# Out:
# 1    0.600000
# 2    0.233333
# 0    0.166667
# Name: gender, dtype: float64

# %% [markdown]
# Для отримання кількості унікальних значень в окремих Series використвують метод unique

# %%
data['birth year'].unique()
# Out:
# array([  nan, 1984., 1986., 1991., 1989., 1976., 1994., 1981., 1990.,
#        1978., 1983., 1987., 1992., 1966., 1972., 1970., 1985.])

# %%
data.corr()
# Out:
# <ipython-input-42-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                          tripduration  start station id  \
# tripduration                 1.000000          0.005958
# start station id             0.005958          1.000000
# start station latitude       0.279717          0.289613
# start station longitude     -0.155065          0.678618
# end station id              -0.208088          0.492051
# end station latitude         0.443372         -0.049569
# end station longitude       -0.015035          0.416501
# bikeid                      -0.083743         -0.000742
# birth year                   0.220732          0.201254
# gender                      -0.228435          0.174797
#
#                          start station latitude  start station longitude  \
# ...

# %%
data.sample(frac=0.2)
# Out:
#     tripduration          starttime           stoptime  start station id  \
# 4            609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
# 23           351  7/1/2016 00:02:05  7/1/2016 00:07:57               490
# 18           464  7/1/2016 00:01:56  7/1/2016 00:09:41               527
# 0            704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 15           533  7/1/2016 00:01:45  7/1/2016 00:10:39               284
# 2            191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
#
#        start station name  start station latitude  start station longitude  \
# 4   Greenwich Ave & 8 Ave               40.739017               -74.002638
# 23        8 Ave & W 33 St               40.751551               -73.993934
# 18        E 33 St & 2 Ave               40.744023               -73.976056
# 0        W 20 St & 11 Ave               40.746745               -74.007756
# 15  Greenwich Ave & 8 Ave               40.739017               -74.002638
# ...

# %%
data['birth year'].sample(n=8, random_state=1)
# Out:
# 17    1983.0
# 21    1966.0
# 10    1986.0
# 19    1992.0
# 14    1978.0
# 20    1983.0
# 26    1985.0
# 3        NaN
# Name: birth year, dtype: float64

# %%
data.to_csv('path_to_file.csv')
print(data)
# Out:
#     tripduration          starttime           stoptime  start station id  \
# 0            704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1            492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2            191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3            687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
# 4            609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
# 5            672  7/1/2016 00:00:45  7/1/2016 00:11:57               459
# 6            466  7/1/2016 00:00:49  7/1/2016 00:08:35               128
# 7            556  7/1/2016 00:00:51  7/1/2016 00:10:07               433
# 8            767  7/1/2016 00:00:51  7/1/2016 00:13:39               254
# 9           1442  7/1/2016 00:00:54  7/1/2016 00:24:56               515
# 10           472  7/1/2016 00:00:55  7/1/2016 00:08:48               319
# 11           777  7/1/2016 00:01:04  7/1/2016 00:14:02               372
# ...

# %% [markdown]
# ### Методи групування даних

# %%
df = pd.read_csv("/content/citibike_dataset/citibike.csv", encoding='latin-1')

# %%
df.groupby(['gender'])

# %%
df.groupby(['gender']).groups
# Out:
# {0: [0, 3, 4, 15, 22], 1: [1, 5, 6, 7, 8, 11, 12, 13, 14, 16, 17, 21, 23, 24, 25, 26, 27, 28], 2: [2, 9, 10, 18, 19, 20, 29]}

# %%
df.groupby(['gender']).first()
# Out:
#         tripduration          starttime           stoptime  start station id  \
# gender
# 0                704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1                492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2                191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
#
#            start station name  start station latitude  \
# gender
# 0            W 20 St & 11 Ave               40.746745
# 1       Lafayette St & E 8 St               40.730287
# 2         N 8 St & Driggs Ave               40.717746
#
#         start station longitude  end station id             end station name  \
# gender
# 0                    -74.007756             347  Greenwich St & W Houston St
# 1                    -73.990765             466              W 25 St & 6 Ave
# 2                    -73.956001            3107     Bedford Ave & Nassau Ave
#
#         end station latitude  end station longitude  bikeid    usertype  \
# gender
# ...

# %%
df.groupby(['gender'])[['tripduration']].mean()
# Out:
#         tripduration
# gender
# 0         952.400000
# 1         842.833333
# 2         570.142857

# %%
df.groupby(['gender']).agg({'tripduration':sum, 'starttime':'first'})
# Out:
#         tripduration          starttime
# gender
# 0               4762  7/1/2016 00:00:02
# 1              15171  7/1/2016 00:00:18
# 2               3991  7/1/2016 00:00:19

# %%
df.groupby(['gender']).agg({'tripduration':[sum, min], 'starttime':'first'})
# Out:
#        tripduration               starttime
#                 sum  min              first
# gender
# 0              4762  533  7/1/2016 00:00:02
# 1             15171  209  7/1/2016 00:00:18
# 2              3991  191  7/1/2016 00:00:19

# %%
df.groupby(['gender']).agg({'tripduration':lambda x: max(x)+1, 'starttime':'first'})
# Out:
#         tripduration          starttime
# gender
# 0               2230  7/1/2016 00:00:02
# 1               2200  7/1/2016 00:00:18
# 2               1443  7/1/2016 00:00:19

# %% [markdown]
# ### Методи перетворення ознак даних

# %%
df.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           704  7/1/2016 00:00:02  7/1/2016 00:11:47               459
# 1           492  7/1/2016 00:00:18  7/1/2016 00:08:31               293
# 2           191  7/1/2016 00:00:19  7/1/2016 00:03:31              3090
# 3           687  7/1/2016 00:00:24  7/1/2016 00:11:52               459
# 4           609  7/1/2016 00:00:31  7/1/2016 00:10:40               284
#
#       start station name  start station latitude  start station longitude  \
# 0       W 20 St & 11 Ave               40.746745               -74.007756
# 1  Lafayette St & E 8 St               40.730287               -73.990765
# 2    N 8 St & Driggs Ave               40.717746               -73.956001
# 3       W 20 St & 11 Ave               40.746745               -74.007756
# 4  Greenwich Ave & 8 Ave               40.739017               -74.002638
#
#    end station id             end station name  end station latitude  \
# ...

# %%
gender={0:'жіноча', 1:'чоловіча'}

# %%
df['gender'].map(gender).head()
# Out:
# 0      жіноча
# 1    чоловіча
# 2         NaN
# 3      жіноча
# 4      жіноча
# Name: gender, dtype: object

# %%
df['tripduration'].apply(lambda x:x/60).head()
# Out:
# 0    11.733333
# 1     8.200000
# 2     3.183333
# 3    11.450000
# 4    10.150000
# Name: tripduration, dtype: float64

# %%
df.apply(lambda x: x['tripduration']/60, axis=1).head()
# Out:
# 0    11.733333
# 1     8.200000
# 2     3.183333
# 3    11.450000
# 4    10.150000
# dtype: float64
